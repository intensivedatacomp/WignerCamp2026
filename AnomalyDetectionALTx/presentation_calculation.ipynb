# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dcintlab/WignerCamp2026/blob/master/AnomalyDetectionALTx/presentation_calculation.ipynb)

# %% [markdown]
# # Generating plots for the presentation

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    drive.mount('/content/drive/')
    # %cd /content/drive/My Drive/Colab Notebooks/WignerCamp2025
except:
    IN_COLAB = False
    # %load_ext autoreload
    # %autoreload 2
print(f'Running on {"Google colab" if IN_COLAB else "Local computer"}')
# Out:
# Running on Local computer

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib as mpl

from functions import *

# %%
from aeon.datasets import load_gunpoint

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sherif",
    "font.size": 25
})

X_train, y_train = load_gunpoint(split="train") # type: ignore
X_test, y_test = load_gunpoint(split="test") # type: ignore


plt.plot(X_train[0, 0, :], lw=3) # type: ignore
plt.xlabel("$t$ (a. u.)")
plt.ylabel("$y$ (a. u.)")
plt.title("Gun point", pad=10)
plt.savefig("../img/Gun_point_time_series_example.pdf", bbox_inches="tight")
