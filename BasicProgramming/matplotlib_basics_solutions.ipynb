# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/dcintlab/WignerCamp2026/blob/main/BasicProgramming/matplotlib_basics_solutions.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # `Matplotlib` Self-Learning Notebook
# This notebook is designed to help you learn the basics of `Matplotlib`. It covers changing markers, line styles, colors, log scales, aspect ratios, adding text to plots, titles, and subplots. Each section includes explanations, examples, and tasks with solutions.
#
# 📚 This notebook is part of the educational materials of Wigner Summer Camp 2026. For further details please visit the project's [GitHub repository](https://github.com/dcintlab/WignerCamp2026).

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    drive.mount('/content/drive/')
    # %cd /content/drive/My Drive/Colab Notebooks/WignerCamp2026
except:
    IN_COLAB = False
print(f'Running on {"Google colab" if IN_COLAB else "Local computer"}')
# Out:
# Running on Local computer

# %% [markdown]
# ## Introduction to `Matplotlib`
# `Matplotlib` is a plotting library for the `Python` programming language and its numerical mathematics extension `NumPy`. It provides an object-oriented `API` for embedding plots into applications.

# %%
# Importing Matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Changing Markers, Line Styles, and Colors
# You can customize the appearance of your plots by changing markers, line styles, and colors.

# %%
# Example plot with different markers, line styles, and colors
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y, marker='o', linestyle='-', color='r', label='Line 1')
plt.plot(x, [15, 25, 20, 35], marker='s', linestyle='--', color='b', label='Line 2')
plt.legend()

# %% [markdown]
# ### Task 1
# Create a plot with the following specifications:
# 1. `x = [1, 2, 3, 4]`
# 2. `y = [5, 10, 15, 20]`
# 3. Use a triangle marker (^), dotted line style (:), and green color

# %%
# Task 1 Solution
x = [1, 2, 3, 4]
y = [5, 10, 15, 20]

plt.plot(x, y, marker='^', linestyle=':', color='g')

# %% [markdown]
# ## Logarithmic Scales
# You can set the scales of the `x`-axis and `y`-axis to logarithmic scales.

# %%
# Example plot with logarithmic scales
x = [1, 10, 100, 1000]
y = [1, 10, 100, 1000]

plt.plot(x, y)
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ### Task 2
# Create a plot with the following specifications:
# 1. `x = [1, 10, 100, 1000]`
# 2. `y = [10, 100, 1000, 10000]`
# 3. Set both axes to logarithmic scales

# %%
# Task 2 Solution
x = [1, 10, 100, 1000]
y = [10, 100, 1000, 10000]

plt.plot(x, y)
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ## Aspect Ratios (optional)
# You can control the aspect ratio of your plots using the `set_aspect` method.

# %%
# Example plot with different aspect ratios
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.figure(figsize=(6, 6))
plt.plot(x, y)
plt.gca().set_aspect('equal')

# %% [markdown]
# ### Task 3
# Create a plot with the following specifications:
# 1. `x = [1, 2, 3, 4, 5]`
# 2. `y = [1, 8, 27, 64, 125]`
# 3. Set the aspect ratio to 1:1

# %%
# Task 3 Solution
x = [1, 2, 3, 4, 5]
y = [1, 8, 27, 64, 125]

plt.figure(figsize=(6, 6))
plt.plot(x, y)
plt.gca().set_aspect('equal')

# %% [markdown]
# ## Adding Text to Plots
# You can add text annotations to your plots using the `text` function.

# %%
# Example plot with text annotations
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y, marker='o')
plt.text(2, 20, 'This is a point')
# Out:
# Text(2, 20, 'This is a point')

# %% [markdown]
# ### Task 4
# Create a plot with the following specifications:
# 1. `x = [1, 2, 3, 4, 5]`
# 2. `y = [2, 4, 6, 8, 10]`
# 3. Add a text annotation at the point (3, 6) with the text 'Mid Point'

# %%
# Task 4 Solution
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o')
plt.text(3, 6, 'Mid Point')
# Out:
# Text(3, 6, 'Mid Point')

# %% [markdown]
# ## Titles
# You can add titles to your plots using the `title` function.

# %%
# Example plot with a title
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y, marker='o')
plt.title('Sample Plot')
# Out:
# Text(0.5, 1.0, 'Sample Plot')

# %% [markdown]
# ### Task 5
# Create a plot with the following specifications:
# 1. `x = [1, 2, 3, 4, 5]`
# 2. `y = [2, 4, 6, 8, 10]`
# 3. Add a title 'Linear Growth'

# %%
# Task 5 Solution
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o')
plt.title('Linear Growth')
# Out:
# Text(0.5, 1.0, 'Linear Growth')

# %% [markdown]
# ## Subplots
# You can create multiple subplots in a single figure using the `subplots` function.

# %%
# Example with multiple subplots
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# First subplot
x1 = [1, 2, 3, 4]
y1 = [10, 20, 25, 30]
ax[0].plot(x1, y1, marker='o')
ax[0].set_title('Subplot 1')

# Second subplot
x2 = [1, 2, 3, 4]
y2 = [30, 25, 20, 10]
ax[1].plot(x2, y2, marker='s')
ax[1].set_title('Subplot 2')
# Out:
# Text(0.5, 1.0, 'Subplot 2')

# %% [markdown]
# ### Task 6
# Create a figure with 2x1 subplots:
# 1. First subplot: `x = [1, 2, 3, 4]`, `y = [5, 10, 15, 20]`, title 'First Plot'
# 2. Second subplot: `x = [1, 2, 3, 4]`, `y = [20, 15, 10, 5]`, title 'Second Plot'

# %%
# Task 6 Solution
fig, ax = plt.subplots(2, 1, figsize=(10, 10))

# First subplot
x1 = [1, 2, 3, 4]
y1 = [5, 10, 15, 20]
ax[0].plot(x1, y1, marker='o')
ax[0].set_title('First Plot')

# Second subplot
x2 = [1, 2, 3, 4]
y2 = [20, 15, 10, 5]
ax[1].plot(x2, y2, marker='s')
ax[1].set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# ## Conclusion
# This notebook provided an introduction to `Matplotlib`, covering changing markers, line styles, colors, log scales, aspect ratios, adding text to plots, titles, and subplots. Practice these concepts to become more comfortable with `Matplotlib`.
