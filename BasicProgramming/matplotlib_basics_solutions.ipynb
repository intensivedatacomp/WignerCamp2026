# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/dcintlab/WignerCamp2026/blob/main/BasicProgramming/matplotlib_basics_solutions.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # `Matplotlib` Self-Learning Notebook
# This notebook is designed to help you learn the basics of `Matplotlib`. It covers changing markers, line styles, colors, LaTeX font settings, adding text to plots, titles, and subplots. Each section includes explanations, examples, and tasks with solutions.
#
# 📚 This notebook is part of the educational materials of Wigner Summer Camp 2026. For further details please visit the project's [GitHub repository](https://github.com/dcintlab/WignerCamp2026).

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    drive.mount('/content/drive/')
    # %cd /content/drive/My Drive/Colab Notebooks/WignerCamp2026
except:
    IN_COLAB = False
    # %load_ext autoreload
    # %autoreload 2
print(f'Running on {"Google colab" if IN_COLAB else "Local computer"}')
# Out:
# Running on Local computer

# %% [markdown]
# ## Introduction to `Matplotlib`
# `Matplotlib` is a plotting library for the `Python` programming language and its numerical mathematics extension `NumPy`. It provides an object-oriented `API` for embedding plots into applications.

# %%
# Importing Matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Changing Markers, Line Styles, and Colors
# You can customize the appearance of your plots by changing markers, line styles, and colors.

# %%
# Example plot with different markers, line styles, and colors
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y, marker='o', linestyle='-', color='r', label='Line 1')
plt.plot(x, [15, 25, 20, 35], marker='s', linestyle='--', color='b', label='Line 2')
plt.legend()

# %% [markdown]
# ### Task 1
# Create a plot with the following specifications:
# 1. `x = [1, 2, 3, 4]`
# 2. `y = [5, 10, 15, 20]`
# 3. Use a triangle marker (^), dotted line style (:), and green color

# %%
# Task 1 Solution
x = [1, 2, 3, 4]
y = [5, 10, 15, 20]

plt.plot(x, y, marker='^', linestyle=':', color='g')

# %% [markdown]
# ## Setting `LaTeX` Fonts
# You can configure the font family, size, and enable `LaTeX` rendering in `Matplotlib` using `plt.rcParams.update()`. This is especially useful for scientific plots where mathematical notation is needed.

# %%
# Example: configuring LaTeX fonts
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": 25
})

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y, marker='o')
plt.title(r'$\sin(x)$ with \LaTeX{} font')
plt.xlabel(r'$x$ (a. u.)')
plt.ylabel(r'$y$ (a. u.)')
# Out:
# Text(0, 0.5, '$y$ (a. u.)')

# %% [markdown]
# ### Task 2
# Configure `Matplotlib` to use `LaTeX` rendering with a serif font at size 18, then create a plot with:
# 1. `x = [0, 1, 2, 3, 4]`
# 2. `y = [0, 1, 4, 9, 16]`
# 3. $x$-axis label: `'$t$ (s)'`
# 4. $y$-axis label: `'$t^2$ (s$^2$)'`

# %%
# Task 2 Solution
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": 18
})

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x, y, marker='o')
plt.xlabel("$t$ (s)")
plt.ylabel("$t^2$ (s$^2$)")
# Out:
# Text(0, 0.5, '$t^2$ (s$^2$)')

# %% [markdown]
# ## Adding Text to Plots
# You can add text annotations to your plots using the `text` function. It is good practice to offset the text position slightly from the data point to avoid overlapping with markers.

# %%
# Example plot with text annotations
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y, marker='o')
plt.text(2.1, 18, 'This is a point')
# Out:
# Text(2.1, 18, 'This is a point')

# %% [markdown]
# ### Task 3
# Create a plot with the following specifications:
# 1. `x = [1, 2, 3, 4, 5]`
# 2. `y = [2, 4, 6, 8, 10]`
# 3. Add a text annotation near the point (3, 6), offset by `(0.1, -0.8)`, with the text `'Mid Point'`.

# %%
# Task 3 Solution
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o')
plt.text(3.1, 5.2, 'Mid Point')
# Out:
# Text(3.1, 5.2, 'Mid Point')

# %% [markdown]
# ## Titles
# You can add titles to your plots using the `title` function. The `pad` argument controls the spacing between the title and the top of the axes in points.

# %%
# Example plot with a title
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y, marker='o')
plt.title('Sample Plot', pad=10)
# Out:
# Text(0.5, 1.0, 'Sample Plot')

# %% [markdown]
# ### Task 4
# Create a plot with the following specifications:
# 1. `x = [1, 2, 3, 4, 5]`
# 2. `y = [2, 4, 6, 8, 10]`
# 3. Add a title `'Linear Growth'` with a padding of `15`.

# %%
# Task 4 Solution
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o')
plt.title('Linear Growth', pad=15)
# Out:
# Text(0.5, 1.0, 'Linear Growth')

# %% [markdown]
# ## Subplots
# You can create multiple subplots in a single figure using the `subplots` function.

# %%
# Example with multiple subplots
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# First subplot
x1 = [1, 2, 3, 4]
y1 = [10, 20, 25, 30]
ax[0].plot(x1, y1, marker='o')
ax[0].set_title('Subplot 1')

# Second subplot
x2 = [1, 2, 3, 4]
y2 = [30, 25, 20, 10]
ax[1].plot(x2, y2, marker='s')
ax[1].set_title('Subplot 2')
# Out:
# Text(0.5, 1.0, 'Subplot 2')

# %% [markdown]
# ### Task 5
# Create a figure with 2x1 subplots:
# 1. First subplot: `x = [1, 2, 3, 4]`, `y = [5, 10, 15, 20]`, title 'First Plot'
# 2. Second subplot: `x = [1, 2, 3, 4]`, `y = [20, 15, 10, 5]`, title 'Second Plot'

# %%
# Task 5 Solution
fig, ax = plt.subplots(2, 1, figsize=(10, 10))

# First subplot
x1 = [1, 2, 3, 4]
y1 = [5, 10, 15, 20]
ax[0].plot(x1, y1, marker='o')
ax[0].set_title('First Plot')

# Second subplot
x2 = [1, 2, 3, 4]
y2 = [20, 15, 10, 5]
ax[1].plot(x2, y2, marker='s')
ax[1].set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# ## Conclusion
# This notebook provided an introduction to `Matplotlib`, covering changing markers, line styles, colors, LaTeX font settings, adding text to plots, titles, and subplots. Practice these concepts to become more comfortable with `Matplotlib`.
