# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/intensivedatacomp/WignerCamp2026/blob/main/GeneralBasicProgramming/opencv_basics.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    drive.mount('/content/drive/')
    # %cd /content/drive/My Drive/HS-25-26
except:
    IN_COLAB = False
    # Updating imports
    # %load_ext autoreload
    # %autoreload 2
print(f'Running on {"Google colab" if IN_COLAB else "Local computer"}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Running on Local computer

# %% [markdown]
# # OpenCV
# OpenCV is an opensurce computer vision libary in `python` and `C++`.

# %% [markdown]
# ## Image read and write

# %%
import cv2
import matplotlib.pyplot as plt

if IN_COLAB:
    img = cv2.imread("/content/drive/My Drive/WignerCamp/img/chair.jpg") 
else:
    img = cv2.imread("../img/chair.jpg") 

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Convert BGR to RGB

plt.imshow(img_rgb) # Display the image
plt.axis("off") # Turn off axis labels and ticks
plt.show() # Show the plot

# %% [markdown]
# ## Resize the image

# %% [markdown]
# ### Resize to `640x480´

# %%
small = cv2.resize(img, (640, 480))

plt.imshow(cv2.cvtColor(small, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# ### Original vs Resized

# %%
small = cv2.resize(img, (640, 480))

fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
ax[0].set_title("Original")
ax[0].axis("off")

ax[1].imshow(cv2.cvtColor(small, cv2.COLOR_BGR2RGB))
ax[1].set_title("Resized")
ax[1].axis("off")

plt.show()

# %% [markdown]
# ## Crop

# %%
crop = img[100:300, 30:500]

plt.imshow(cv2.cvtColor(crop, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %% [markdown]
# ## Convert to gray scale image

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap="gray")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Canny Edge Detector
# __Canny__ is a classical edge detector algorithm

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 100, 200)

plt.imshow(edges, cmap="gray")
plt.axis("off")
plt.show()

# %% [markdown]
# # Tasks:
# * make a code when __read and write__ `cat.jpg`
# * __resize__ `cat.jpg` to `(280,500)`
# * tell: `What is the different between __oroginal and resized__ images
# * __crop__ to `[:,:]`
# * convert to __gray scaled__
# * use __Canny Edge Detection__
